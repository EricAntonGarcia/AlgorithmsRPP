# %% [markdown]
# ## Knock-In algorithm:
# ### The idea is to find reactions which their flux diminishes as the protein production increases. Then among these reactions find the essential genes for growth rate (preliminar candidates). Next, include the expression of an ectopic gene and check if the lethal cell fitness caused by the Knock-Out of the preliminar candidates could be rescued.

# %%
import cobra
import escher
import pandas as pd
import numpy as np
import json
import csv
from cobra.io import save_json_model
from cobra import Reaction
from cobra.flux_analysis.loopless import add_loopless, loopless_solution
from scipy.stats import linregress

# %%
cobra.Configuration().solver = "cplex"

# %%
#model_path = 'iMT1026v3.xml'
#model_path = 'iPichia.xml'
model_path = './models/iMT1026v3jup.xml'

model = cobra.io.read_sbml_model(model_path)

model
# Out:
# <Model iMT1026v3 at 0x2b93299f448>

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Ex_biomass = 0.04850771827866006</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glyc_e</td>
#       <td>Ex_glyc</td>
#       <td>0.9538</td>
#       <td>3</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>Ex_nh4</td>
#       <td>0.3009</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>Ex_o2</td>
#       <td>1.616</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>Ex_pi</td>
#       <td>0.0122</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>Ex_so4</td>
#       <td>0.002127</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>biomass_e</td>
#       <td>Ex_biomass</td>
#       <td>-0.04851</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>Ex_co2</td>
#       <td>-1.163</td>
#       <td>1</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>Ex_h</td>
#       <td>-0.3153</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>Ex_h2o</td>
#       <td>-2.735</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Change grwoth on glycerol to growth on 60% glucose and 40% methanol
# Add reaction describing this growth

biomass_gly = model.reactions.get_by_id('BIOMASS_glyc')
biomass_gly.bounds = (0,0)
biomass_gly

carbs = model.metabolites.get_by_id('CARBOHYDRATES_c')
DNA = model.metabolites.get_by_id('DNA_c')
lipids = model.metabolites.get_by_id('LIPIDS_c')
prot = model.metabolites.get_by_id('PROTEIN_c')
RNA = model.metabolites.get_by_id('RNA_c')
atp = model.metabolites.get_by_id('atp_c')
cof = model.metabolites.get_by_id('cof_c')
h2o = model.metabolites.get_by_id('h2o_c')
adp = model.metabolites.get_by_id('adp_c')
biomass = model.metabolites.get_by_id('biomass_c')
h = model.metabolites.get_by_id('h_c')
pi = model.metabolites.get_by_id('pi_c')

biomass_glc_meoh = Reaction ('biomass_glc_meoh_60/40')
biomass_glc_meoh.name = 'Biomass composition (g/g) - 60/40 Glucose/Methanol'
biomass_glc_meoh.add_metabolites({carbs: -0.33,
                                   DNA: -0.001,
                                   lipids: -0.042,
                                   prot: -0.49,
                                   RNA: -0.058,
                                   atp: -63.85,
                                   cof: -1,
                                   h2o: -63.85,
                                   adp: 63.85,
                                   pi: 63.85,
                                   biomass: 1,
                                   h: 63.85})
biomass_glc_meoh
# Out:
# <Reaction biomass_glc_meoh_60/40 at 0x2b93c576188>

# %%
# Add new biomass reaction to the model

print (len(model.reactions))
model.add_reactions([biomass_glc_meoh])
print (len(model.reactions))
# Out:
# 2237
# 2238

# %%
#Tanquem l'entrada de Glicerol
glycerol_exchange = model.exchanges.get_by_id('Ex_glyc')
glycerol_exchange.bounds = (0,0)
glycerol_exchange
# Out:
# <Reaction Ex_glyc at 0x2b93bba53c8>

# %%
methanol_exchange = model.exchanges.get_by_id('Ex_meoh')
methanol_exchange.bounds = (-1.24, -1.18) #Glucose60_Methanol 40
methanol_exchange
# Out:
# <Reaction Ex_meoh at 0x2b93bba5d08>

# %%
glucose_exchange = model.reactions.get_by_id('Ex_glc_D')
glucose_exchange.bounds = (-0.74, -0.72) #Glucose20_Methanol80
glucose_exchange
# Out:
# <Reaction Ex_glc_D at 0x2b93bb87288>

# %%
# Change the reactions for the synthesis of lipids, proteins and sterols from glycerol to those from glucose

model.reactions.get_by_id('LIPIDS_glyc').bounds = (0,0)
model.reactions.get_by_id('PROTEINS_glyc').bounds = (0,0)
model.reactions.get_by_id('STEROLS_glyc').bounds = (0,0)

# note: these reactions from glucose do not have the glucose specification
model.reactions.get_by_id('LIPIDS').bounds = (0,1000)
model.reactions.get_by_id('PROTEINS').bounds = (0,1000)
model.reactions.get_by_id('STEROLS').bounds = (0,1000)

# %%
# ATP maintenance requirement (NGAME = Non-Growth Associated Maintenance Energy) based on previous studies on 
# the growth of X33-ROL on Gluc/MeOH from the group (Eric's Master Thesis)

model.reactions.get_by_id('ATPM').bounds = (1.96, 1000)

# %%
rolAA = model.reactions.get_by_id('rolAA')
rolAA.bounds = (0,1000)
rolRNA = model.reactions.get_by_id('rolRNA')
rolRNA.bounds = (0,1000)
rolDNA = model.reactions.get_by_id('rolDNA')
rolDNA.bounds = (0,1000)
pROL = model.reactions.get_by_id('pROL')
pROL.bounds = (0,1000)
Rol_transport =  model.reactions.get_by_id('ROLt')
Rol_transport.bounds = (0,1000)
ROL_exchange = model.exchanges.get_by_id('Ex_rol')
#ROL_exchange.bounds = (0.0003773,1000)
ROL_exchange.bounds = (0.003,1000) # Inferit de Bradford

pFAB = model.reactions.get_by_id('pFAB')
pFAB.bounds = (0,0)
fabAA = model.reactions.get_by_id('fabAA')
fabAA.bounds = (0,0)
fabt = model.reactions.get_by_id('fabt')
fabt.bounds = (0,0)
fabRNA = model.reactions.get_by_id('fabRNA')
fabRNA.bounds = (0,0)
fabDNA = model.reactions.get_by_id('fabDNA')
FAB_exchange = model.exchanges.get_by_id('Ex_fab')
FAB_exchange.bounds = (0,0)


# Extra reactions that must be closed for simulations to run smoothly:

APAT2r = model.reactions.get_by_id('APAT2r')
APAT2r.bounds = (0,0) # reaction not present in Pichia, it is yet to be removed from the model

MMSAD3 = model.reactions.get_by_id('MMSAD3')
MMSAD3.bounds = (0,0) # The reduction reaction of MSA into Acetil-CoA it is due to an unspecific effect. Reaction
# under evaluation of being kept or not.

# %%
#Creating the cPOS5 reaction
atp_c = model.metabolites.get_by_id('atp_c')
nadh_c = model.metabolites.get_by_id('nadh_c')
adp_c = model.metabolites.get_by_id('adp_c')
nadph_c = model.metabolites.get_by_id('nadph_c')
h_c = model.metabolites.get_by_id('h_c')

cPOS5 = Reaction('cPOS5')
cPOS5.name = 'Cytosolic NADH Kinase from Saccharomyces cerevisiae'
cPOS5.add_metabolites({atp_c: -1, 
                           nadh_c: -1, 
                           adp_c: 1, 
                           nadph_c: 1,
                               h_c: 1})
cPOS5.bounds = (0,0)
print (cPOS5.reaction)
cPOS5

# from Saccharomyces. Found in Brenda ('for references in articles please use BRENDA:EC2.7.1.86')
# Also in Uniprot with ID Q06892 and ID YPL188W (Saccharomyces Genome Database)
# It is a kinase from the mitochondrial matrix (Outten and Culotta, 2003)
# Although it is a mitochondrial enzyme in Saccharomyces, Marius et al. (2) added a tag to express it in the cytosol
# you sure about the above? It says in page of his thesis that it was truncated: they removed the first 49 bp of the
# gene in order to remove the peptide leading sequence, ensuring that it would stay in the cytosol and not go to the
# mitochondria
# Out:
# atp_c + nadh_c --> adp_c + h_c + nadph_c
# <Reaction cPOS5 at 0x2b93c57e148>

# %%
print (len(model.reactions))
model.add_reactions([cPOS5])
print (len(model.reactions))
# Out:
# 2238
# 2239

# %% [markdown]
# ## Reaction Ratios as constraints
#
# ### The experimental data was extracted from the paper:
# #### "Metabolic flux analysis of recombinant Pichia pastoris growing on different glycerol/methanol mixtures by iterative fitting of NMR-derived 13C labelling data from proteinogenic amino acids" by Joel Jordà, 2014

# %%
# REACTION RATIOS PER GLUCOSA METANOL

ReactionRatio1 = model.problem.Constraint(model.reactions.CSm.flux_expression - model.reactions.ACONTm.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio1)

ReactionRatio2 = model.problem.Constraint(model.reactions.AKGDam.flux_expression - model.reactions.FUMm.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio2)

ReactionRatio8 = model.problem.Constraint(68*model.reactions.AKGDam.flux_expression - 46*model.reactions.CSm.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio8)

ReactionRatio9 = model.problem.Constraint(model.reactions.G6PDH2.flux_expression - model.reactions.GND.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio9)

ReactionRatio10 = model.problem.Constraint(0.8*model.reactions.MDHm.flux_expression - model.reactions.FUMm.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio10)

ReactionRatio12 = model.problem.Constraint(35*model.reactions.PYK.flux_expression - 143*model.reactions.PC.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio12)

ReactionRatio13 = model.problem.Constraint(68*model.reactions.PYK.flux_expression - 143*model.reactions.PYRt2m.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio13)


ReactionRatio14 = model.problem.Constraint(40*model.reactions.GAPD.flux_expression - 145*model.reactions.FBA.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio14)


ReactionRatio16 = model.problem.Constraint(model.reactions.GAPD.flux_expression - model.reactions.PYK.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio16)

ReactionRatio20 = model.problem.Constraint(0.18*model.reactions.FALDtx.flux_expression - 0.82*model.reactions.DAS.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio20)

ReactionRatio21 = model.problem.Constraint(model.reactions.G6PDH2.flux_expression + 0.4*model.reactions.Ex_glc_D.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio21)

# %%
pfba_WT = cobra.flux_analysis.pfba(model)
#pfba_WT = loopless_solution(model)

# %%
pfba_WT.fluxes['Ex_rol']
# Out:
# 0.003

# %%
pfba_WT.fluxes['Ex_biomass']
# Out:
# 0.08254928084409742

# %% [markdown]
# ## MOMA Simulations
#
# ### Carbon Source: Glc/MeOH

# %%
# Remove Reaction Ratio Constraints before starting MOMA simulations

ReactionRatioList = [ReactionRatio1, ReactionRatio2, ReactionRatio8, ReactionRatio9, ReactionRatio10,
                     ReactionRatio12, ReactionRatio13, ReactionRatio14, ReactionRatio16, ReactionRatio20, ReactionRatio21]
                    

model.remove_cons_vars(ReactionRatioList)

# %%
NewRolProd = (0.0033, 0.0036, 0.0039, 0.0042, 0.0045, 0.0048)

# %%
#MOMA non-linear Simulations 
MomaResults = []
for x in NewRolProd:
        ROL_exchange.bounds = (x, x)
        
        # Perform MOMA
        moma_result = cobra.flux_analysis.moma(model,pfba_WT,0) #Boolean per si el MOMA es lineal o no
        MomaResults.append(moma_result.fluxes)

# %%
#Identify reaction which their flux is diminished as the protein production increases.
decreased_reactions = []
slopes = {}

for reaction in model.reactions:

    reaction_id = reaction.id

    moma_fluxes = [
        MomaResults[0][reaction_id],
        MomaResults[1][reaction_id],
        MomaResults[2][reaction_id],
        MomaResults[3][reaction_id],
        MomaResults[4][reaction_id],
        MomaResults[5][reaction_id]
    ]

    # Absolute flux
    moma_fluxes_abs = np.abs(moma_fluxes)

    # Linear regression: absolute reaction flux vs protein production
    slope, intercept, r_value, p_value, std_err = linregress(
        NewRolProd,
        moma_fluxes_abs
    )

    slopes[reaction_id] = slope

    # Decreasing absolute flux
    if slope < -0.05:
        decreased_reactions.append(reaction_id)

# %%
#Determine which are the essential reactions from the previous generated list
essential_reactions = []
fba_knockdown_growth_results = {}

ROL_exchange.bounds = (0, 1000)

for reaction_id in decreased_reactions:

    print(f"Testing {reaction_id}...")

    with model:

        reaction = model.reactions.get_by_id(reaction_id)
        reaction.bounds = (0, 0)

        # Run FBA
        solution = model.optimize()

        # Check solver status
        status = model.solver.status

        print(f"    Solver status: {status}")

        if status == "infeasible":
            print(f"    {reaction_id} → INFEASIBLE → ESSENTIAL")
            essential_reactions.append(reaction_id)
            fba_knockdown_growth_results[reaction_id] = "infeasible"
            continue

        # Only access fluxes if solution is feasible
        growth = solution.fluxes['Ex_biomass']

        print(f"    Growth = {growth}")

        fba_knockdown_growth_results[reaction_id] = growth

        if growth < 0.01:
            print(f"    {reaction_id} → ESSENTIAL")
            essential_reactions.append(reaction_id)
# Out:
# Testing NADH2_u6mh...
#     Solver status: optimal
#     Growth = 0.08331550416744382
# Testing FAcoaRavge...
#     Solver status: optimal
#     Growth = -0.0
#     FAcoaRavge → ESSENTIAL
# Testing 3C4MOPtm...
#     Solver status: optimal
#     Growth = 0.09875014542331262
# Testing ACtp...
#     Solver status: optimal
#     Growth = 0.09880219511797977
# Testing CITtap...
#     Solver status: optimal
#     Growth = 0.09880219511798022
# Testing DESAT18_2...
#     Solver status: optimal
#     Growth = -0.0
#     DESAT18_2 → ESSENTIAL
# Testing DOLPt2er...
#     Solver status: optimal
#     Growth = 0.09868504676962706
# Testing MANNANter...
#     Solver status: optimal
#     Growth = 0.0987240653419898
# Testing CYOR_u6m...
#     Solver status: optimal
#     Growth = 0.06705759701120599
# Testing ACACT1m...
#     Solver status: optimal
#     Growth = 0.09875062860649769
# Testing ACSp...
#     Solver status: optimal
#     Growth = 0.09880219488893653
# Testing ALDD2y...
#     Solver status: optimal
#     Growth = 0.09880219488893653
# Testing ASPt2m...
#     Solver status: optimal
#     Growth = 0.09880219488893653
# Testing ATPtm_H...
#     Solver status: infeasible
#     ATPtm_H → INFEASIBLE → ESSENTIAL
# Testing dolpmmer...
# C:\Users\Eric\miniconda3\envs\s2m2\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#     Solver status: optimal
#     Growth = 0.09872406442274488
# Testing GCC2cm...
#     Solver status: optimal
#     Growth = 0.09880219419895298
# Testing GLCt1...
#     Solver status: infeasible
#     GLCt1 → INFEASIBLE → ESSENTIAL
# Testing H2Oter...
#     Solver status: optimal
#     Growth = 0.0988021941978707
# Testing HMGCOASm...
#     Solver status: optimal
#     Growth = 0.0987506279154611
# Testing ICDHxm...
#     Solver status: optimal
#     Growth = 0.0988021941981525
# Testing ICDHym...
#     Solver status: optimal
#     Growth = 0.0988021941981525
# Testing MEVK2...
#     Solver status: optimal
#     Growth = 0.0988021941987292
# Testing NADH2_u6cm...
#     Solver status: optimal
#     Growth = 0.0988021941981525
# Testing OMCDCm...
#     Solver status: optimal
#     Growth = 0.09875014450499325
# Testing PIt2m...
#     Solver status: infeasible
#     PIt2m → INFEASIBLE → ESSENTIAL
# Testing DHORD4i...
#     Solver status: optimal
#     Growth = 0.09880219442803875
# Testing GLUt7m...
#     Solver status: optimal
#     Growth = 0.09864232792550225
# Testing FALDH2...
#     Solver status: optimal
#     Growth = 0.09803021624258128
# Testing FALGTHLs...
#     Solver status: optimal
#     Growth = 0.09803021624314583
# Testing MAN1PT2...
#     Solver status: optimal
#     Growth = 0.09868498213991507
# Testing PDHa1...
#     Solver status: optimal
#     Growth = -0.0
#     PDHa1 → ESSENTIAL
# Testing PDHa2...
#     Solver status: optimal
#     Growth = 0.09610940812343428
# Testing PPItx...
#     Solver status: optimal
#     Growth = 0.09880219468661311
# Testing FCYTB5R...
#     Solver status: optimal
#     Growth = 0.09879516249302499
# Testing FCYTDESAT18...
#     Solver status: optimal
#     Growth = 0.09879516249246598
# Testing PDHbrm...
#     Solver status: optimal
#     Growth = 0.09610940812200729
# Testing LIPIDS...
#     Solver status: optimal
#     Growth = -0.0
#     LIPIDS → ESSENTIAL
# Testing growth...
#     Solver status: infeasible
#     growth → INFEASIBLE → ESSENTIAL
# Testing 4MOPtm...
#     Solver status: infeasible
#     4MOPtm → INFEASIBLE → ESSENTIAL
# Testing G5SADsm...
#     Solver status: infeasible
#     G5SADsm → INFEASIBLE → ESSENTIAL
# Testing PROTEINS...
#     Solver status: optimal
#     Growth = -0.0
#     PROTEINS → ESSENTIAL
# Testing CARBOHYDRATES...
#     Solver status: optimal
#     Growth = -0.0
#     CARBOHYDRATES → ESSENTIAL
# Testing RNA...
#     Solver status: infeasible
#     RNA → INFEASIBLE → ESSENTIAL
# Testing COF...
#     Solver status: optimal
#     Growth = -0.0
#     COF → ESSENTIAL
# Testing METOHte...
#     Solver status: infeasible
#     METOHte → INFEASIBLE → ESSENTIAL
# Testing METOHtx...
#     Solver status: infeasible
#     METOHtx → INFEASIBLE → ESSENTIAL
# Testing O2tx...
#     Solver status: optimal
#     Growth = 0.0973635180214706
# Testing 13GS...
#     Solver status: optimal
#     Growth = -0.0
#     13GS → ESSENTIAL
# Testing ACCOACr...
#     Solver status: infeasible
#     ACCOACr → INFEASIBLE → ESSENTIAL
# Testing ACGAM6PS...
#     Solver status: infeasible
#     ACGAM6PS → INFEASIBLE → ESSENTIAL
# Testing ACGAMPM...
#     Solver status: optimal
#     Growth = -0.0
#     ACGAMPM → ESSENTIAL
# Testing ACGKm...
#     Solver status: optimal
#     Growth = -0.0
#     ACGKm → ESSENTIAL
# Testing ACOATA...
#     Solver status: optimal
#     Growth = -0.0
#     ACOATA → ESSENTIAL
# Testing ACONTm...
#     Solver status: infeasible
#     ACONTm → INFEASIBLE → ESSENTIAL
# Testing ACOTAim...
#     Solver status: infeasible
#     ACOTAim → INFEASIBLE → ESSENTIAL
# Testing ACS...
#     Solver status: infeasible
#     ACS → INFEASIBLE → ESSENTIAL
# Testing ADSL2r...
#     Solver status: optimal
#     Growth = 5.45987025393508e-12
#     ADSL2r → ESSENTIAL
# Testing AGPRim...
#     Solver status: optimal
#     Growth = -0.0
#     AGPRim → ESSENTIAL
# Testing AIRCr...
#     Solver status: infeasible
#     AIRCr → INFEASIBLE → ESSENTIAL
# Testing ASPCT...
#     Solver status: infeasible
#     ASPCT → INFEASIBLE → ESSENTIAL
# Testing ASPTAm...
#     Solver status: optimal
#     Growth = 0.09643023578380817
# Testing ATP2tp_H...
#     Solver status: optimal
#     Growth = 0.09880219462908355
# Testing ATPS3m...
#     Solver status: optimal
#     Growth = 0.016285306407068774
# Testing CATp...
#     Solver status: optimal
#     Growth = 0.0867166183472438
# Testing CHTNS...
#     Solver status: optimal
#     Growth = 0.09868685282767996
# Testing CITtam...
#     Solver status: optimal
#     Growth = 0.09877734571461666
# Testing CITtcm...
#     Solver status: optimal
#     Growth = 0.09880219462931755
# Testing CSp...
#     Solver status: optimal
#     Growth = 0.09880219462931755
# Testing CYTK1...
#     Solver status: optimal
#     Growth = 0.09878974180790984
# Testing DHORTS...
#     Solver status: optimal
#     Growth = -0.0
#     DHORTS → ESSENTIAL
# Testing DMATT...
#     Solver status: optimal
#     Growth = -0.0
#     DMATT → ESSENTIAL
# Testing DOLPMTcer...
#     Solver status: optimal
#     Growth = -0.0
#     DOLPMTcer → ESSENTIAL
# Testing DPMVD...
#     Solver status: infeasible
#     DPMVD → INFEASIBLE → ESSENTIAL
# Testing ENO...
#     Solver status: infeasible
#     ENO → INFEASIBLE → ESSENTIAL
# Testing FDH...
#     Solver status: optimal
#     Growth = 0.09802459168719467
# Testing GALU...
#     Solver status: optimal
#     Growth = -0.0
#     GALU → ESSENTIAL
# Testing GARFTi...
#     Solver status: infeasible
#     GARFTi → INFEASIBLE → ESSENTIAL
# Testing GLCS2...
#     Solver status: optimal
#     Growth = -0.0
#     GLCS2 → ESSENTIAL
# Testing GLUPRT...
#     Solver status: optimal
#     Growth = -0.0
#     GLUPRT → ESSENTIAL
# Testing GMPS2...
#     Solver status: infeasible
#     GMPS2 → INFEASIBLE → ESSENTIAL
# Testing GRTT...
#     Solver status: optimal
#     Growth = -0.0
#     GRTT → ESSENTIAL
# Testing H2Otm...
#     Solver status: optimal
#     Growth = 0.09880219488781469
# Testing H2Otp...
#     Solver status: optimal
#     Growth = 0.09759097341533043
# Testing HMGCOAR...
#     Solver status: optimal
#     Growth = -0.0
#     HMGCOAR → ESSENTIAL
# Testing HMGCOAtm...
#     Solver status: optimal
#     Growth = 0.0987506303278703
# Testing IMPD...
#     Solver status: optimal
#     Growth = 0.09877354290389385
# Testing IPDDI...
#     Solver status: optimal
#     Growth = -0.0
#     IPDDI → ESSENTIAL
# Testing MAN6PI...
#     Solver status: optimal
#     Growth = -0.0
#     MAN6PI → ESSENTIAL
# Testing MCOATA...
#     Solver status: optimal
#     Growth = -0.0
#     MCOATA → ESSENTIAL
# Testing METS...
#     Solver status: optimal
#     Growth = -0.0
#     METS → ESSENTIAL
# Testing MTHFR3...
#     Solver status: optimal
#     Growth = -0.0
#     MTHFR3 → ESSENTIAL
# Testing O2t...
#     Solver status: infeasible
#     O2t → INFEASIBLE → ESSENTIAL
# Testing O2tm...
#     Solver status: infeasible
#     O2tm → INFEASIBLE → ESSENTIAL
# Testing OAAt2m...
#     Solver status: optimal
#     Growth = 0.09880219488833614
# Testing OMPDC...
#     Solver status: optimal
#     Growth = -0.0
#     OMPDC → ESSENTIAL
# Testing ORNt3m...
#     Solver status: optimal
#     Growth = -0.0
#     ORNt3m → ESSENTIAL
# Testing ORNTACim...
#     Solver status: optimal
#     Growth = -0.0
#     ORNTACim → ESSENTIAL
# Testing ORPT...
#     Solver status: optimal
#     Growth = -0.0
#     ORPT → ESSENTIAL
# Testing PGM...
#     Solver status: infeasible
#     PGM → INFEASIBLE → ESSENTIAL
# Testing PGMT...
#     Solver status: optimal
#     Growth = -0.0
#     PGMT → ESSENTIAL
# Testing PIt2r...
#     Solver status: optimal
#     Growth = 2.6404321726550507e-12
#     PIt2r → ESSENTIAL
# Testing PMANM...
#     Solver status: optimal
#     Growth = -0.0
#     PMANM → ESSENTIAL
# Testing PMEVK...
#     Solver status: infeasible
#     PMEVK → INFEASIBLE → ESSENTIAL
# Testing PRAGSr...
#     Solver status: infeasible
#     PRAGSr → INFEASIBLE → ESSENTIAL
# Testing PRAIS...
#     Solver status: optimal
#     Growth = -0.0
#     PRAIS → ESSENTIAL
# Testing PRASCS...
#     Solver status: optimal
#     Growth = -0.0
#     PRASCS → ESSENTIAL
# Testing PRFGS...
#     Solver status: optimal
#     Growth = -5.463290175180762e-12
#     PRFGS → ESSENTIAL
# Testing PYK...
#     Solver status: optimal
#     Growth = 0.09504978427647189
# Testing PYRDC...
#     Solver status: optimal
#     Growth = 0.09880219549134758
# Testing RPE...
#     Solver status: optimal
#     Growth = 0.09658028364800392
# Testing SFGTH...
#     Solver status: optimal
#     Growth = 0.09803021726386085
# Testing TALA...
#     Solver status: optimal
#     Growth = 0.0986460525437686
# Testing UDPACGLP...
#     Solver status: optimal
#     Growth = -0.0
#     UDPACGLP → ESSENTIAL
# Testing CYOOm...
#     Solver status: optimal
#     Growth = 0.06709395001689406
# Testing AGTi...
#     Solver status: optimal
#     Growth = 0.09880219557778136
# Testing AOD...
#     Solver status: infeasible
#     AOD → INFEASIBLE → ESSENTIAL
# Testing DAS...
#     Solver status: optimal
#     Growth = 0.097394047051324
# Testing PSERS_PP...
#     Solver status: optimal
#     Growth = 0.09880152649737588
# Testing PSERDm_PP...
#     Solver status: optimal
#     Growth = 0.09880157442757678
# Testing PStm_PP...
#     Solver status: optimal
#     Growth = 0.09880157442757678
# Testing COAtim...
#     Solver status: optimal
#     Growth = 0.0987506288625622
# Testing PEtm_PP...
#     Solver status: optimal
#     Growth = 0.09880157442716637
# Testing DHAtx...
#     Solver status: optimal
#     Growth = 0.09880219514604217
# Testing G3Ptx...
#     Solver status: optimal
#     Growth = 0.09739404704475874
# Testing FALDtx...
#     Solver status: optimal
#     Growth = 0.09803021732067199
# Testing XU5Ptx...
#     Solver status: optimal
#     Growth = 0.09739404705096888
# Testing Ht...
#     Solver status: optimal
#     Growth = 0.09612562679490111
# Testing Ex_glc_D...
#     Solver status: optimal
#     Growth = 0.013922572915447518
# Testing Ex_pi...
#     Solver status: optimal
#     Growth = -0.0
#     Ex_pi → ESSENTIAL
# Testing Ex_h...
#     Solver status: optimal
#     Growth = 0.09880219566458895
# Testing Ex_o2...
#     Solver status: infeasible
#     Ex_o2 → INFEASIBLE → ESSENTIAL
# Testing Ex_meoh...
#     Solver status: optimal
#     Growth = 0.07635803200372808
# Testing Ex_biomass...
#     Solver status: optimal
#     Growth = 0.0
#     Ex_biomass → ESSENTIAL
# Testing Htr...
#     Solver status: optimal
#     Growth = -0.0
#     Htr → ESSENTIAL
# Testing FAS1_4...
#     Solver status: optimal
#     Growth = -0.0
#     FAS1_4 → ESSENTIAL
# Testing FAS1_6...
#     Solver status: optimal
#     Growth = 1.0897494272736729e-12
#     FAS1_6 → ESSENTIAL
# Testing FAS1_8...
#     Solver status: optimal
#     Growth = -0.0
#     FAS1_8 → ESSENTIAL
# Testing FAS1_10...
#     Solver status: optimal
#     Growth = -0.0
#     FAS1_10 → ESSENTIAL
# Testing FAS1_12...
#     Solver status: optimal
#     Growth = -0.0
#     FAS1_12 → ESSENTIAL
# Testing FAS2_4...
#     Solver status: infeasible
#     FAS2_4 → INFEASIBLE → ESSENTIAL
# Testing FAS2_6...
#     Solver status: infeasible
#     FAS2_6 → INFEASIBLE → ESSENTIAL
# Testing FAS2_8...
#     Solver status: optimal
#     Growth = -0.0
#     FAS2_8 → ESSENTIAL
# Testing FAS2_10...
#     Solver status: infeasible
#     FAS2_10 → INFEASIBLE → ESSENTIAL
# Testing FAS2_12...
#     Solver status: optimal
#     Growth = -0.0
#     FAS2_12 → ESSENTIAL
# Testing FAS3_4...
#     Solver status: optimal
#     Growth = -0.0
#     FAS3_4 → ESSENTIAL
# Testing FAS3_6...
#     Solver status: infeasible
#     FAS3_6 → INFEASIBLE → ESSENTIAL
# Testing FAS3_8...
#     Solver status: infeasible
#     FAS3_8 → INFEASIBLE → ESSENTIAL
# Testing FAS3_10...
#     Solver status: infeasible
#     FAS3_10 → INFEASIBLE → ESSENTIAL
# Testing FAS3_12...
#     Solver status: optimal
#     Growth = -0.0
#     FAS3_12 → ESSENTIAL
# Testing FAS4_4...
#     Solver status: infeasible
#     FAS4_4 → INFEASIBLE → ESSENTIAL
# Testing FAS4_6...
#     Solver status: optimal
#     Growth = -0.0
#     FAS4_6 → ESSENTIAL
# Testing FAS4_8...
#     Solver status: optimal
#     Growth = -0.0
#     FAS4_8 → ESSENTIAL
# Testing FAS4_10...
#     Solver status: optimal
#     Growth = -0.0
#     FAS4_10 → ESSENTIAL
# Testing FAS4_12...
#     Solver status: optimal
#     Growth = -0.0
#     FAS4_12 → ESSENTIAL
# Testing FAS5_12...
#     Solver status: optimal
#     Growth = 0.09880219462940622
# Testing FAE1_14...
#     Solver status: optimal
#     Growth = 0.09880219462909873
# Testing FAE1_16...
#     Solver status: optimal
#     Growth = 0.0988021946290897
# Testing FAE1_18...
#     Solver status: optimal
#     Growth = 0.09880219462909873
# Testing FAE2_14...
#     Solver status: optimal
#     Growth = 0.09880219462909873
# Testing FAE2_16...
#     Solver status: optimal
#     Growth = 0.09880219462909873
# Testing FAE2_18...
#     Solver status: optimal
#     Growth = 0.09880219462909873
# Testing FAE3_14...
#     Solver status: optimal
#     Growth = 0.09880219462909968
# Testing FAE3_16...
#     Solver status: optimal
#     Growth = 0.09880219462909873
# Testing FAE3_18...
#     Solver status: optimal
#     Growth = 0.09880219462909873
# Testing FAE4_14...
#     Solver status: optimal
#     Growth = 0.09880219462909968
# Testing FAE4_16...
#     Solver status: optimal
#     Growth = 0.09880219462909873
# Testing FAE4_18...
#     Solver status: optimal
#     Growth = 0.09880219462909873
# Testing biomass_glc_meoh_60/40...
#     Solver status: optimal
#     Growth = -0.0
#     biomass_glc_meoh_60/40 → ESSENTIAL

# %%
rescued_reactions = []
rescue_results = {}

# Express POS5
cPOS5.bounds = (0.11, 0.11)

for reaction_id in essential_reactions:

    with model:

        # Knock out the essential reaction
        reaction = model.reactions.get_by_id(reaction_id)
        reaction.bounds = (0, 0)

        # Run FBA
        solution = model.optimize()

        if solution.status == "infeasible":
            rescue_results[reaction_id] = {
                "KO_growth": fba_knockdown_growth_results[reaction_id],
                "POS5_growth": "infeasible",
                "rescued": False
            }
            continue

        growth = solution.fluxes["Ex_biomass"]

        # Store results
        rescue_results[reaction_id] = {
            "KO_growth": fba_knockdown_growth_results[reaction_id],
            "POS5_growth": growth,
            "rescued": growth >= 0.01
        }

        # Add to rescued reactions
        if growth >= 0.01:
            rescued_reactions.append(reaction_id)

# %%
rescued_reactions
# Out:
# ['4MOPtm', 'G5SADsm', 'ACONTm', 'ACS', 'ENO', 'PGM']

# %%
rescue_results
# Out:
# {'FAcoaRavge': {'KO_growth': -0.0,
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'DESAT18_2': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'ATPtm_H': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'GLCt1': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'PIt2m': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'PDHa1': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'LIPIDS': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'growth': {'KO_growth': 'infeasible', 'POS5_growth': -0.0, 'rescued': False},
#  '4MOPtm': {'KO_growth': 'infeasible',
#   'POS5_growth': 0.09846216903082747,
#   'rescued': True},
#  'G5SADsm': {'KO_growth': 'infeasible',
#   'POS5_growth': 0.09845829573123087,
#   'rescued': True},
#  'PROTEINS': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'CARBOHYDRATES': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'RNA': {'KO_growth': 'infeasible', 'POS5_growth': -0.0, 'rescued': False},
#  'COF': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'METOHte': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'METOHtx': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  '13GS': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'ACCOACr': {'KO_growth': 'infeasible',
#   'POS5_growth': 1.1193369674162937e-12,
#   'rescued': False},
#  'ACGAM6PS': {'KO_growth': 'infeasible',
#   'POS5_growth': -0.0,
#   'rescued': False},
#  'ACGAMPM': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'ACGKm': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'ACOATA': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'ACONTm': {'KO_growth': 'infeasible',
#   'POS5_growth': 0.09851406527463923,
#   'rescued': True},
#  'ACOTAim': {'KO_growth': 'infeasible', 'POS5_growth': -0.0, 'rescued': False},
#  'ACS': {'KO_growth': 'infeasible',
#   'POS5_growth': 0.0985140653893218,
#   'rescued': True},
#  'ADSL2r': {'KO_growth': 5.45987025393508e-12,
#   'POS5_growth': -0.0,
#   'rescued': False},
#  'AGPRim': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'AIRCr': {'KO_growth': 'infeasible',
#   'POS5_growth': -7.287574520931069e-12,
#   'rescued': False},
#  'ASPCT': {'KO_growth': 'infeasible', 'POS5_growth': -0.0, 'rescued': False},
#  'DHORTS': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'DMATT': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'DOLPMTcer': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'DPMVD': {'KO_growth': 'infeasible', 'POS5_growth': -0.0, 'rescued': False},
#  'ENO': {'KO_growth': 'infeasible',
#   'POS5_growth': 0.09442385722596033,
#   'rescued': True},
#  'GALU': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'GARFTi': {'KO_growth': 'infeasible', 'POS5_growth': -0.0, 'rescued': False},
#  'GLCS2': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'GLUPRT': {'KO_growth': -0.0,
#   'POS5_growth': -1.658997919191162e-11,
#   'rescued': False},
#  'GMPS2': {'KO_growth': 'infeasible', 'POS5_growth': -0.0, 'rescued': False},
#  'GRTT': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'HMGCOAR': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'IPDDI': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'MAN6PI': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'MCOATA': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'METS': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'MTHFR3': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'O2t': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'O2tm': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'OMPDC': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'ORNt3m': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'ORNTACim': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'ORPT': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'PGM': {'KO_growth': 'infeasible',
#   'POS5_growth': 0.09442385873458586,
#   'rescued': True},
#  'PGMT': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'PIt2r': {'KO_growth': 2.6404321726550507e-12,
#   'POS5_growth': -1.50097598204073e-11,
#   'rescued': False},
#  'PMANM': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'PMEVK': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'PRAGSr': {'KO_growth': 'infeasible', 'POS5_growth': -0.0, 'rescued': False},
#  'PRAIS': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'PRASCS': {'KO_growth': -0.0,
#   'POS5_growth': 1.4564843879652598e-11,
#   'rescued': False},
#  'PRFGS': {'KO_growth': -5.463290175180762e-12,
#   'POS5_growth': -0.0,
#   'rescued': False},
#  'UDPACGLP': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'AOD': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'Ex_pi': {'KO_growth': -0.0,
#   'POS5_growth': -2.696967649207238e-12,
#   'rescued': False},
#  'Ex_o2': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'Ex_biomass': {'KO_growth': 0.0, 'POS5_growth': 0.0, 'rescued': False},
#  'Htr': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'FAS1_4': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'FAS1_6': {'KO_growth': 1.0897494272736729e-12,
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'FAS1_8': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'FAS1_10': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'FAS1_12': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'FAS2_4': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'FAS2_6': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'FAS2_8': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'FAS2_10': {'KO_growth': 'infeasible', 'POS5_growth': -0.0, 'rescued': False},
#  'FAS2_12': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'FAS3_4': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'FAS3_6': {'KO_growth': 'infeasible', 'POS5_growth': -0.0, 'rescued': False},
#  'FAS3_8': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'FAS3_10': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'FAS3_12': {'KO_growth': -0.0, 'POS5_growth': -0.0, 'rescued': False},
#  'FAS4_4': {'KO_growth': 'infeasible',
#   'POS5_growth': 'infeasible',
#   'rescued': False},
#  'FAS4_6': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'FAS4_8': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'FAS4_10': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'FAS4_12': {'KO_growth': -0.0, 'POS5_growth': 'infeasible', 'rescued': False},
#  'biomass_glc_meoh_60/40': {'KO_growth': -0.0,
#   'POS5_growth': -0.0,
#   'rescued': False}}

# %% [markdown]
# ### After performing the simulations the obtained rescued reactions list should be manually curated discarding the exchange reactions, transport by diffusion, reactions without gene rule...

# %%
rescued_reactions_curated = ['NADH2_u6mh','G5SADsm','FAS5_12']

# %%
moma_rescued_reactions_results = {}
cPOS5.bounds = (0.11, 0.11)
ROL_exchange.bounds = (0, 1000)

for reaction_id in rescued_reactions_curated:

    with model:

        # Knock out the rescued reaction
        reaction = model.reactions.get_by_id(reaction_id)
        reaction.bounds = (0, 0)

        # Run MOMA
        moma_result = cobra.flux_analysis.moma(model,pfba_WT,0)

        if moma_result.status == "infeasible":
            moma_rescue_results[reaction_id] = {
                "growth": "infeasible",
                "ROL_production": "infeasible"
            }
            print(f"{reaction_id}: INFEASIBLE")
            continue

        # Get biomass and protein production
        growth = moma_result.fluxes["Ex_biomass"]
        rol_production = moma_result.fluxes["Ex_rol"]

        # Store results
        moma_rescued_reactions_results[reaction_id] = {
            "growth": growth,
            "ROL_production": rol_production
        }

        print(
            f"{reaction_id}: "
            f"Growth = {growth:.6f}, "
            f"ROL production = {rol_production:.6f}"
        )
# Out:
# NADH2_u6mh: Growth = 0.066066, ROL production = 0.005002
# G5SADsm: Growth = 0.079769, ROL production = 0.004345
# FAS5_12: Growth = 0.079835, ROL production = 0.004338
